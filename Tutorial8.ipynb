# %% [markdown]
# # Exercise:
#
# In this exercise, you will work with a data set in "mtcars.csv" that contains information on 31 cars. We will create a collection of scatterplots showing the relationship between horsepower (hp) and miles per gallon (mpg), displacement(disp) and quarter mile time (qsec).  Also, in each of these plots we will distinguish between automatic (am = 0) and manual (am=1) cars. Please follow the following steps:
#
# **Step 0:** create a gitHub repository for this exercise. In your local repository, copy this jupyter file. Make sure you commit and push changes to your online repository after each step.
#
# **Step 1:** Read the file into a data frame
#
# **Step 2:** Dispaly statistics about differnt columns
#
# **Step 3:** Create two dataframes from the origial one to represent manual and automatic cars
#
# **Step 4:** Now Let's first create a 1x3 figure on which we will place the three plots. Give the figure a title of "Understanding the Effect of Horspower on other Features"
#
# **Step 5:** On the first axis plot hp versus miles per gallon for manual cars only
#
# **Step 6:** Add to the same axis a plot for automatic car, using a different color
#
# **Step 7:** Repeat 5 and 6 for hp vs qsec
#
# **Step 8:** Repeat 5 and 6 for hp vs disp
#
# **Step 9:** Use descriptive labels, good markers, colors, and legends to enhance your graph
#
# **Step 10:** Save figures to your computer
#
#
# Advanced: Add two horizontal lines to the first plot denoting the respective average mpg for automatic and manual cars
# respectively.
#
# test.

# %%
import pandas as pd
df = pd.read_csv("mtcars(2).csv")

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
automatic = df.loc[df['am'] == 0]
automatic.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
#
#    carb
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2

# %%
manual = df.loc[df['am'] == 1]
manual.head()
# Out:
#             model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 17       Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18    Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
#
#     carb
# 0      4
# 1      4
# 2      1
# 17     1
# 18     2

# %%
import matplotlib.pyplot as plt
import matplotlib
import statistics

# %%
x = statistics.mean(manual_sorted['mpg'])

# %%
fig = plt.figure()
fig, ax = plt.subplots(1, 3, figsize= (10,5))
fig.suptitle("Understanding the Effect of Horspower on other Features")


ax[0].scatter(manual['hp'], manual['mpg'],label = 'manual car', marker = 'x', c = 'g')
ax[0].scatter(automatic['hp'], automatic['mpg'],label = 'manual car', marker = 'o',c = 'r')
ax[0].axhline(y=(statistics.mean(manual['mpg'])), color='g',linestyle='--',)
ax[0].axhline(y=(statistics.mean(automatic['mpg'])), color='r',linestyle='--',)
ax[0].set_xlabel('Horse Power')
ax[0].set_ylabel('Miles Per Gallon')



ax[1].scatter(manual['hp'], manual['qsec'], marker = 'x', c = 'g')
ax[1].scatter(automatic['hp'], automatic['qsec'], marker = 'o', c = 'r')
ax[1].set_xlabel('Horse Power')
ax[1].set_ylabel('Quarter Mile Time')

ax[2].scatter(manual['hp'], manual['disp'], marker = 'x',  c = 'g')
ax[2].scatter(automatic['hp'], automatic['disp'], marker = 'o', c = 'r')
ax[2].set_xlabel('Horse Power')
ax[2].set_ylabel('Displacement')




## create legend for the figure, attached to 'label'
fig.legend(loc='upper center', bbox_to_anchor=(0.525, 0.001), shadow=False, ncol=2)
plt.tight_layout()
plt.show()

# %%
fig.savefig("carplots.png", bbox_inches = "tight")
